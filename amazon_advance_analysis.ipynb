# %% [markdown]
# # Goal
#
# The goal of this notebook is to explore Amazon reviews and see if bias exist between different reviewers.

# %% [markdown]
# ### Notes/Thoughts/Reminders
#
# ### This is an ongoing analysis
#
# Need to separate the analysis between series and movies
# Need to test the mean score and compare to two groups
# Compare mean and calculate variance
# Run t-test or Wilcoxon test as appropriate
#
# Run to see if there is concensus group of reviewers that review most similarly.

# %% [markdown]
# ## Environment Setup and Dependencies

# %%
# Dependencies
import os

# set spark version
spark_version = 'spark-3.0.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark


# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:8 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 256 kB in 3s (100 kB/s)
# Reading package lists... Done

# %%
# setup pyspark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("AmazonAnalysis")\
  .config("spark.driver.extraClassPath","/content/postgresql-42.2.9.jar")\
  .getOrCreate()

# %% [markdown]
# # Extract
# *  Create connectiont to S3 bucket and file

# %% [markdown]
# DATA COLUMNS:
# marketplace- 2 letter country code of the marketplace where the review was written.
# customer_id       - Random identifier that can be used to aggregate reviews written by a single author.
# review_id         - The unique ID of the review.
# product_id        - The unique Product ID the review pertains to. In the multilingual dataset the reviews
#                     for the same product in different countries can be grouped by the same product_id.
# product_parent    - Random identifier that can be used to aggregate reviews for the same product.
# product_title     - Title of the product.
# product_category  - Broad product category that can be used to group reviews
#                     (also used to group the dataset into coherent parts).
# star_rating       - The 1-5 star rating of the review.
# helpful_votes     - Number of helpful votes.
# total_votes       - Number of total votes the review received.
# vine              - Review was written as part of the Vine program.
# verified_purchase - The review is on a verified purchase.
# review_headline   - The title of the review.
# review_body       - The review text.
# review_date       - The date the review was written.
#
# DATA FORMAT
# Tab ('\t') separated text file, without quote or escape characters.
# First line in each file is header; 1 line corresponds to 1 record.

# %%
# add files to pyspark
from pyspark import SparkFiles

# Load file
# https://s3.amazonaws.com/amazon-reviews-pds/tsv/index.txt
url = "https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Digital_Video_Download_v1_00.tsv.gz" 
filename = "amazon_reviews_us_Digital_Video_Download_v1_00.tsv.gz"
spark.sparkContext.addFile(url)

# read file
df = spark.read.csv(SparkFiles.get(filename), header=True, inferSchema=True, sep='\t', timestampFormat="mm/dd/yy")
df.show(10)
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |marketplace|customer_id|     review_id|product_id|product_parent|       product_title|    product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |         US|   12190288|R3FU16928EP5TC|B00AYB1482|     668895143|Enlightened: Seas...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|I loved it and I ...|I loved it and I ...| 2015-08-31|
# |         US|   30549954|R1IZHHS1MH3AQ4|B00KQD28OM|     246219280|             Vicious|Digital_Video_Dow...|          5|            0|          0|   N|                Y|As always it seem...|As always it seem...| 2015-08-31|
# |         US|   52895410| R52R85WC6TIAH|B01489L5LQ|     534732318|         After Words|Digital_Video_Dow...|          4|           17|         18|   N|                Y|      Charming movie|This movie isn't ...| 2015-08-31|
# |         US|   27072354| R7HOOYTVIB0DS|B008LOVIIK|     239012694|Masterpiece: Insp...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|excellant this is...| 2015-08-31|
# |         US|   26939022|R1XQ2N5CDOZGNX|B0094LZMT0|     535858974|   On The Waterfront|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Brilliant film fr...|Brilliant film fr...| 2015-08-31|
# |         US|    4772040|R1HCST57W334KN|B0112OSOQE|      38517795|Rick and Morty Se...|Digital_Video_Dow...|          5|            5|          6|   N|                Y|Best show on TV r...|If you don't like...| 2015-08-31|
# |         US|   12910040|R32BUTYQS1ZJBQ|B000NPE5SA|     373323715|      Africa Screams|Digital_Video_Dow...|          4|            1|          1|   N|                Y|Very funny. A typ...|Very funny.  A ty...| 2015-08-31|
# |         US|   38805573|  RH4SXPL4L9QU|B00XWV4QXG|     633842417| Entourage: Season 7|Digital_Video_Dow...|          3|            0|          0|   N|                Y|it was not as goo...|Strange as it is,...| 2015-08-31|
# |         US|   37100714|R37INWIQA5YW8N|B00X8UKOUK|     666093513|Catastrophe - Sea...|Digital_Video_Dow...|          2|            0|          0|   N|                Y|           Two Stars|Funny shows! We l...| 2015-08-31|
# |         US|   41234409|R18GSVAAS3N8GX|B00OOKXTFU|     801680808|The Worricker Tri...|Digital_Video_Dow...|          3|            0|          0|   N|                Y|        A tad Stuffy|Well made. Great ...| 2015-08-31|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# only showing top 10 rows

# %%
df.groupby('vine').count().show()
# Out:
# +----+-------+
# |vine|  count|
# +----+-------+
# |   N|4057147|
# +----+-------+

# %% [markdown]
# # Transform
# *  Remove bad and duplicated records
# *  Check number of records left
# *  Convert column datatypes if needed

# %%
# size of dataframe (rows)
print(df.count())

# drop incomplete records
df = df.dropna()
print(df.count())

# drop duplicated records (if any; should be none)
df = df.dropDuplicates()
print(df.count())

# check datatypes
df.printSchema()
# Out:
# 4057147
# 4056518
# 4056518
# root
#  |-- marketplace: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- product_parent: integer (nullable = true)
#  |-- product_title: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- star_rating: integer (nullable = true)
#  |-- helpful_votes: integer (nullable = true)
#  |-- total_votes: integer (nullable = true)
#  |-- vine: string (nullable = true)
#  |-- verified_purchase: string (nullable = true)
#  |-- review_headline: string (nullable = true)
#  |-- review_body: string (nullable = true)
#  |-- review_date: string (nullable = true)

# %%
# convert review-date to date format
from pyspark.sql.functions import to_date, col
complete_table = df.withColumn("review_date", to_date(col("review_date"),"yyyy-MM-dd").alias("review_date"))

# check change
complete_table.printSchema()
# Out:
# root
#  |-- marketplace: string (nullable = true)
#  |-- customer_id: integer (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- product_parent: integer (nullable = true)
#  |-- product_title: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- star_rating: integer (nullable = true)
#  |-- helpful_votes: integer (nullable = true)
#  |-- total_votes: integer (nullable = true)
#  |-- vine: string (nullable = true)
#  |-- verified_purchase: string (nullable = true)
#  |-- review_headline: string (nullable = true)
#  |-- review_body: string (nullable = true)
#  |-- review_date: date (nullable = true)

# %% [markdown]
# ## General Review
# - What questions do I formulate from looking at the data?

# %%
complete_table.show(5)
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |marketplace|customer_id|     review_id|product_id|product_parent|       product_title|    product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |         US|   51950426|R1005KN8L3OP23|B00COTH9VI|     956367867|Seeking Asian Female|Digital_Video_Dow...|          5|            1|          1|   N|                Y|What a great docu...|What a great docu...| 2015-04-07|
# |         US|   42507369|R1008R0427X1FG|B009KHHELW|      41559476|Duck Dynasty Seas...|Digital_Video_Dow...|          4|            0|          0|   N|                Y|        reality show|This series has m...| 2014-05-28|
# |         US|    2458036|R100AJRT6FE05K|B0048ZXXIO|     814772102|Team Umizoomi Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Educational for kids|My kid loves this...| 2014-06-27|
# |         US|   23459444|R100AOYGH18ZXK|B00GBDWZDU|     936264488|     Christmas Crush|Digital_Video_Dow...|          3|            0|          0|   N|                Y|         Three Stars|kind of dragged a...| 2015-05-20|
# |         US|   38247406|R100BC7LPZKRNN|B007SPQZMC|     192466294|Downton Abbey Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|Now I understand ...|I didn't know wha...| 2013-03-13|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# only showing top 5 rows

# %%
complete_table.agg({'review_date': 'max'}).show()
# Out:
# +----------------+
# |max(review_date)|
# +----------------+
# |      2015-08-31|
# +----------------+

# %%
complete_table.agg({'review_date': 'min'}).show()
# Out:
# +----------------+
# |min(review_date)|
# +----------------+
# |      2000-10-04|
# +----------------+

# %%
complete_table.groupby('vine').agg({'vine':'count', 'star_rating':'mean', 'star_rating':'stddev'}).show()

# %% [markdown]
# Review Comments:
# *  Most columns are pretty self-explanitory
# *  Intiail thought is that I need to specifically target the `customer_id`, `product_title`, and `vine` status to determine bias relationships
# *  Need to check to see what these columns mean or affect the data:
#   *  `product_parent`
#   *  `vine`
#   *  `verified_purchase`
# *  Should probably go to Amazon and check out one of the titles and the reviews section since that is where this info should come from.

# %% [markdown]
# ## Customer Inspection

# %%
from pyspark.sql.functions import col, asc,desc
top_customers = complete_table.groupby('customer_id').agg({'customer_id': 'count', 'star_rating': 'mean', 'star_rating':'stddev'}).sort(col('count(customer_id)').desc())
top_customers.show()
# Out:
# +-----------+-------------------+------------------+
# |customer_id|stddev(star_rating)|count(customer_id)|
# +-----------+-------------------+------------------+
# |   43430756| 1.1466950029602812|              2745|
# |   39122522| 1.4677304463865763|               707|
# |   30160665| 1.3412714675001378|               579|
# |   49382242| 1.1040682379826534|               527|
# |   50605810| 0.7162294922476529|               496|
# |   12714026| 1.2588258102987135|               474|
# |   20052283| 0.8957312551423887|               469|
# |    5291529| 0.8632297187933043|               434|
# |   17486470| 1.4211032675673525|               402|
# |   44167709|  1.075516254256177|               393|
# |   22263100| 0.9857063376341949|               386|
# |   42398245|  1.031430340340169|               374|
# |   50818682| 1.1828674484054744|               357|
# |   27106921| 1.6445530191414834|               338|
# |   41926755| 1.1660943116267561|               334|
# |   12653036|  1.116638223221243|               327|
# |   45450659| 0.6118319779379569|               306|
# |   19087887|   0.84279369379535|               297|
# |   16380876| 0.2305974663778343|               285|
# |   14945970| 0.9442518685476451|               281|
# +-----------+-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# Above shows that the reviewers with a significant number of reviews score movies very differently.  It's not clear how the reviewers would score the same set of movies but taking a sample of over 300 movies the average rating ranged between 2.58 to 4.64.  Analyzing for survey response bias will be a separate notebook since that is a more involved process and there is a chance that with the number of reviews here that some interesting information can be extracted.

# %% [markdown]
# ## Product Parent Inspection

# %%
# not sure what product_parent means; check several values
review_list = complete_table.filter('product_parent == 534732318')
review_list.show()
# Out:
# +-----------+-----------+--------------+----------+--------------+-------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |marketplace|customer_id|     review_id|product_id|product_parent|product_title|    product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|
# +-----------+-----------+--------------+----------+--------------+-------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |         US|   21405234|R228VZZCNNJZY9|B01489L5LQ|     534732318|  After Words|Digital_Video_Dow...|          3|            4|          8|   N|                Y|Four stars go to ...|The best of the m...| 2015-08-23|
# |         US|   37232123|R2RVE4TNX16LM7|B01489L5LQ|     534732318|  After Words|Digital_Video_Dow...|          5|            3|          4|   N|                Y|A Librarians New ...|Very nice story a...| 2015-08-24|
# |         US|   51341168|R2KRK2YMZ2Z4AW|B013SLOXWS|     534732318|  After Words|Digital_Video_Dow...|          5|           11|         14|   N|                N|I'm packing my ba...|AFTER WORDS is a ...| 2015-08-18|
# |         US|    2406827|R3SZW3IDEIIARS|B01489MLS2|     534732318|  After Words|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|Shows how the bea...| 2015-08-31|
# |         US|   52895410| R52R85WC6TIAH|B01489L5LQ|     534732318|  After Words|Digital_Video_Dow...|          4|           17|         18|   N|                Y|      Charming movie|This movie isn't ...| 2015-08-31|
# |         US|   13948952| RA11C3IT83PN5|B01489L5LQ|     534732318|  After Words|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|A thought provoki...| 2015-08-24|
# |         US|   29902039|R27A1Q3D9EF4AY|B01489MLS2|     534732318|  After Words|Digital_Video_Dow...|          3|            0|          0|   N|                Y|          Cute movie|Loved seeing what...| 2015-08-31|
# |         US|   25102274|R3E4XMDV0OIYQ7|B013SLO5TY|     534732318|  After Words|Digital_Video_Dow...|          5|            2|          2|   N|                N|Fell in love with...|Is sooooo loved t...| 2015-08-21|
# |         US|   21819371|R15VE46DYSWJ1Q|B01489L5LQ|     534732318|  After Words|Digital_Video_Dow...|          4|            0|          0|   N|                Y|      Worth watching|Good story. Beaut...| 2015-08-30|
# +-----------+-----------+--------------+----------+--------------+-------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+

# %%
review_product_parent_record = complete_table.filter('product_parent == 853694223')
review_product_parent_record.show()
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |marketplace|customer_id|     review_id|product_id|product_parent| product_title|    product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|
# +-----------+-----------+--------------+----------+--------------+--------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# |         US|   51739130|R1TIXBUT10IETQ|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|Great series.<br ...| 2015-08-29|
# |         US|   36609931|R1I5DO9T0YY62H|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|         Great show!|Fantastic interpr...| 2015-08-28|
# |         US|   31750160|R366U4CD3GQKDX|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|          Great show| 2015-08-27|
# |         US|   14740295|R3HBM5GFTCRUG3|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|Good choice for t...| 2015-08-27|
# |         US|   15843688|R1LRLH3LWVJ1JA|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|   excellent acting.|Well done, excell...| 2015-08-22|
# |         US|   36505851|R3GFC1ZJB3FZBB|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|Bosch is pretty good|Show is almost as...| 2015-08-22|
# |         US|   52724431|R3I7OD9NW6L9J8|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|I enjoyed  the pl...| 2015-08-18|
# |         US|   34525206|R1MU92YV6PFM65|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|        Great series| 2015-08-09|
# |         US|   50185373|R2ZCTY2Z2IMRKM|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|    Very good series| 2015-08-08|
# |         US|   30062911|R35QEYUCXXVKTT|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          3|            0|          0|   N|                Y|I am beginning to...|Initially, I wasn...| 2015-07-31|
# |         US|   20778533|R34NA0A5TOK893|B00I3NHZPY|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Well Done!|Loved the first s...| 2015-07-22|
# |         US|   13516204|R2EP9XJDQ12RPP|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|Good suspenseful ...|Scary plot, good ...| 2015-07-22|
# |         US|   16017210|R14HGZ4C6GCCXL|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|nicely paced, gre...|Atmospheric, nice...| 2015-07-22|
# |         US|   15026686|R1FG57ITEG7DMD|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|         Enjoyed it.| 2015-07-22|
# |         US|   38732934| RUV69KLW9QH19|B00I3NHZPY|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Emmy nominations ...|Really enjoyed th...| 2015-07-19|
# |         US|   49795756|R3D186BCP42S94|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|It's good you wil...| 2015-07-18|
# |         US|   15310350| R2VXI93FR4DDP|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|Almost as good as...| 2015-07-18|
# |         US|   29385686| RHRKYH8F89HW5|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Must watch|I read, and liked...| 2015-07-13|
# |         US|   51643256|R2P1V4AK143HK9|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|       Great series!|This is a great s...| 2015-07-13|
# |         US|   39089279|R2Q3TPRVWZ38ON|B00I3MQNWG|     853694223|Bosch Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|Awesome. Love Mic...| 2015-07-09|
# +-----------+-----------+--------------+----------+--------------+--------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
review_product_parent_record.groupby('product_title').agg({'product_title':'count'}).show()
# Out:
# +--------------------+--------------------+
# |       product_title|count(product_title)|
# +--------------------+--------------------+
# |Bosch Season 1 [U...|                1056|
# |Chapter Three:  B...|                  21|
# |Chapter Four:  Fu...|                  38|
# |Chapter Seven:  L...|                  43|
# |Bosch: The Offici...|                 225|
# |Chapter Ten:  Us ...|                 400|
# |Chapter Two:  Los...|                  49|
# |Chapter Five:  Ma...|                  38|
# |               Pilot|                9351|
# |Bosch: Behind the...|                  97|
# |Chapter Six:  Don...|                  30|
# | Bosch: A Look Ahead|                  31|
# |Chapter Nine: The...|                  85|
# |Chapter Eight:  H...|                  65|
# |      Bosch Season 1|               53158|
# +--------------------+--------------------+

# %% [markdown]
# Product Parent Comments:
# *  shows that product parent is a grouping of related movie titles
# *  product parent is probably a better filter metric for standard movies but not series.
# *  Do sequels to movies fall into the same product parent code?

# %%
top_product_parent_expanded = complete_table.groupby('product_parent').agg({'product_parent': 'count', 'star_rating': 'mean', 'star_rating':'stddev', 'product_title':'max'}).sort(col('count(product_parent)').desc())
top_product_parent_expanded.show()
# Out:
# +--------------+---------------------+-------------------+--------------------+
# |product_parent|count(product_parent)|stddev(star_rating)|  max(product_title)|
# +--------------+---------------------+-------------------+--------------------+
# |     853694223|                64687| 0.7329521807324126|               Pilot|
# |     360747388|                24950| 1.1258722151064684|Why Do We Cover t...|
# |     192466294|                24144| 0.5700737413464739|Downton Abbey: Or...|
# |     459613388|                23975| 0.4972830325471113|Episode 8 (Origin...|
# |     730000855|                18240| 0.6925583220789996|            Veterans|
# |      82685115|                17550| 0.9197108370275767|You Have Insulted...|
# |     756881760|                16604|  1.213892423084143|             Zingers|
# |     593966951|                16410| 1.1536516590701158|Under The Dome, S...|
# |      47146773|                15618| 1.3262660051632356|The After Exclusi...|
# |     682981764|                14573| 0.4606111994134379|Original UK Versi...|
# |     666093513|                14059|  1.008530368170614|           Episode 6|
# |     940561470|                13724| 0.7173832104050191|Variations Under ...|
# |     530546487|                13155| 0.5957201982678061|    Season 4 Preview|
# |      68901493|                12311|  0.691272347357231|       The New World|
# |     147054708|                12143| 0.7120368903557512|Wrath of the Nort...|
# |     388470662|                11362| 0.7606501479879042|            Trust Me|
# |     728197314|                11342| 0.6988521903760821|      Woman in Black|
# |     714145608|                10866| 0.9904998027883879|  Wish You Were Here|
# |     479335063|                10624| 0.7453617303162914|Sneaky Pete - Sea...|
# |     371110390|                10334| 1.1010327976935828|        Jack Reacher|
# +--------------+---------------------+-------------------+--------------------+
# only showing top 20 rows

# %%
top_reviewed_titles = complete_table.groupby('product_parent', 'product_title').agg({'product_title':'count', 'product_parent':'max', 'star_rating':'mean'}).sort(col('count(product_title)').desc())
top_reviewed_titles.show()
# Out:
# +--------------+--------------------+-------------------+------------------+--------------------+
# |product_parent|       product_title|max(product_parent)|  avg(star_rating)|count(product_title)|
# +--------------+--------------------+-------------------+------------------+--------------------+
# |     853694223|      Bosch Season 1|          853694223| 4.606098799804357|               53158|
# |     192466294|Downton Abbey Sea...|          192466294| 4.857869514040693|               23788|
# |     459613388|Downton Abbey Sea...|          459613388| 4.873770078210411|               23782|
# |     360747388|Transparent Season 1|          360747388| 4.463614140654381|               21272|
# |     730000855|  Justified Season 1|          730000855| 4.679647684467095|               18052|
# |     593966951|Under The Dome, S...|          593966951| 4.153612511309293|               15474|
# |     682981764|Downton Abbey Sea...|          682981764| 4.892263246899661|               14192|
# |     666093513|Catastrophe - Sea...|          666093513|4.4402194333809275|               13307|
# |      82685115|Mozart in the Jun...|           82685115| 4.514141337959122|               13259|
# |     940561470|Orphan Black Seas...|          940561470| 4.682845442135599|               13186|
# |     530546487|Downton Abbey Sea...|          530546487| 4.836667179566087|               12998|
# |     756881760|Alpha House Season 1|          756881760| 4.267007197585326|               12921|
# |     147054708|    Vikings Season 1|          147054708| 4.681612090680101|               11910|
# |     388470662|The Americans Sea...|          388470662| 4.615094678273356|               11143|
# |     728197314|      Grimm Season 1|          728197314| 4.650957819947837|               11119|
# |     714145608|    Extant, Season 1|          714145608| 4.299733231707317|               10496|
# |     371110390|        Jack Reacher|          371110390|3.9156183472034063|               10334|
# |     109782764|                Noah|          109782764|2.2656589606797075|               10122|
# |     642045560|Alpha House Season 2|          642045560| 4.677539514748817|                9933|
# |     981104076|    The Hunger Games|          981104076| 4.229340101522842|                9850|
# +--------------+--------------------+-------------------+------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Vine Reviewer Inspection

# %%
complete_table.groupby('vine').agg({'vine':'count', 'star_rating':'mean', 'star_rating':'stddev'}).show()
# Out:
# +----+-------------------+-----------+
# |vine|stddev(star_rating)|count(vine)|
# +----+-------------------+-----------+
# |   N| 1.2234969947632452|    4056518|
# +----+-------------------+-----------+

# %%
complete_table.filter(complete_table.vine == Y).describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6f44c99d7b42> in <module>()
# ----> 1 complete_table.filter(complete_table.vine == Y).describe()
#
# NameError: name 'Y' is not defined

# %%
complete_table.filter('vine == N').describe()

# %% [markdown]
# # Feature Modification
# *  Identify series
# *  One-Hot-Encode `star_rating`

# %% [markdown]
# ## Identify Series Shows

# %%
from pyspark.sql.functions import col, asc,desc, lit
type_list = complete_table.product_title.contains("Season")

# %%
type_list.dtypes
# Out:
# Column<b'contains(product_title, Season)[dtypes]'>

# %%
complete_table = complete_table.withColumn('isSeries', type_list)
complete_table.show()
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+--------+
# |marketplace|customer_id|     review_id|product_id|product_parent|       product_title|    product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|isSeries|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+--------+
# |         US|   51950426|R1005KN8L3OP23|B00COTH9VI|     956367867|Seeking Asian Female|Digital_Video_Dow...|          5|            1|          1|   N|                Y|What a great docu...|What a great docu...| 2015-04-07|   false|
# |         US|   42507369|R1008R0427X1FG|B009KHHELW|      41559476|Duck Dynasty Seas...|Digital_Video_Dow...|          4|            0|          0|   N|                Y|        reality show|This series has m...| 2014-05-28|    true|
# |         US|    2458036|R100AJRT6FE05K|B0048ZXXIO|     814772102|Team Umizoomi Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Educational for kids|My kid loves this...| 2014-06-27|    true|
# |         US|   23459444|R100AOYGH18ZXK|B00GBDWZDU|     936264488|     Christmas Crush|Digital_Video_Dow...|          3|            0|          0|   N|                Y|         Three Stars|kind of dragged a...| 2015-05-20|   false|
# |         US|   38247406|R100BC7LPZKRNN|B007SPQZMC|     192466294|Downton Abbey Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|Now I understand ...|I didn't know wha...| 2013-03-13|    true|
# |         US|   45431492|R100E6GW7T8K8T|B00TPJE3ZK|     351396917|             Birdman|Digital_Video_Dow...|          4|            0|          1|   N|                Y|Well portrayed, c...|Great acting and ...| 2015-02-20|   false|
# |         US|   53047960| R100IRNYUYV1E|B00J7JY812|     540211273|Orphan Black, Sea...|Digital_Video_Dow...|          4|            0|          0|   N|                Y|Great performance...|Great performance...| 2015-04-23|    true|
# |         US|   19482080|R100K3H25R5WS0|B003AZCYCE|     730000855|  Justified Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                N|             Amazing|This is an amazin...| 2013-10-30|    true|
# |         US|   48973249|R100PJ9LCWDNMK|B009HND1VG|     687442758|Death and The Civ...|Digital_Video_Dow...|          4|            2|          3|   N|                N|Audio Book Was Be...|Although the film...| 2014-03-12|   false|
# |         US|   42529217|R100SWYL64JWQ9|B003363I3O|     106600129|LEGO: The Adventu...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|                   1| 2015-01-21|   false|
# |         US|   43368651|R1012ZSHZ8EUJY|B004GTS81E|      38097401|   Cranford Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                N|   Wonderful Series!|I just loved this...| 2013-06-05|    true|
# |         US|   45675760|R1018I6GYR9RXC|B00KFVWXPE|     938841809|The Sopranos: Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|          Great show|This is a great s...| 2014-06-05|    true|
# |         US|   42254329| R101AQNQEQNH1|B006885LZM|     224139336|The Pacific Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|Loved the 1st sea...| 2015-04-30|    true|
# |         US|   15216617|R101FJHAGGVHVL|B00DTOYJJ2|     109469328|Breaking Bad The ...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Greatest televisi...|Best series EVER!...| 2014-01-06|    true|
# |         US|   50896799|R1023HVVLBIBYV|B000I9X6NG|     572506954|Dodgeball: A True...|Digital_Video_Dow...|          1|            1|          2|   N|                Y|             Bad....|   Dumb and crude...| 2015-07-14|   false|
# |         US|   35379296|R102MSR65GHIXU|B004JVXTL8|     408493771|Paranormal Activi...|Digital_Video_Dow...|          5|            0|          0|   N|                N|          Terrifying|This movie was fr...| 2015-01-09|   false|
# |         US|   15303482|R1031FV2PBZTZ4|B004KAJLNS|     192466294|Downton Abbey Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|Downton Abbey Sea...|This is a fantast...| 2014-01-14|    true|
# |         US|   27051750|R103DUOHT7I4OT|B00F91RYL8|     757136861|         World War Z|Digital_Video_Dow...|          5|            0|          1|   N|                Y|          Five Stars|  Great zombie movie| 2015-03-10|   false|
# |         US|   21780294|R103LYSTYMF48T|B00VLQX1GC|     464287565|        Last Knights|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|I liked it, best ...| 2015-08-19|   false|
# |         US|   20237654|R103N41PJJN0VE|B00FEHXCIG|     272231685|Iron Man 3 (Theat...|Digital_Video_Dow...|          3|            0|          0|   N|                Y|Cool action scene...|As you would expe...| 2013-11-26|   false|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+--------+
# only showing top 20 rows

# %%
complete_table.groupby('isSeries').agg({'isSeries':'count', 'star_rating':'mean', 'helpful_votes':'sum'}).show()
# Out:
# +--------+-----------------+------------------+---------------+
# |isSeries| avg(star_rating)|sum(helpful_votes)|count(isSeries)|
# +--------+-----------------+------------------+---------------+
# |    true|4.602062651843032|            360543|        1553825|
# |   false|3.952329750392877|           1667937|        2502693|
# +--------+-----------------+------------------+---------------+

# %% [markdown]
# ## Separate `star_rating` into own columns

# %%
from pyspark.sql.functions import udf, col
from pyspark.sql.types import IntegerType

for i in [1,2,3,4,5]:
    function = udf(lambda item: 
                   1 if item == i else 0, 
                   IntegerType())
    new_column_name = "is"+'_'+ str(i)
    complete_table = complete_table.withColumn(new_column_name, function(col("star_rating")))
complete_table.show()
# Out:
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+--------+----+----+----+----+----+
# |marketplace|customer_id|     review_id|product_id|product_parent|       product_title|    product_category|star_rating|helpful_votes|total_votes|vine|verified_purchase|     review_headline|         review_body|review_date|isSeries|is_1|is_2|is_3|is_4|is_5|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+--------+----+----+----+----+----+
# |         US|   51950426|R1005KN8L3OP23|B00COTH9VI|     956367867|Seeking Asian Female|Digital_Video_Dow...|          5|            1|          1|   N|                Y|What a great docu...|What a great docu...| 2015-04-07|   false|   0|   0|   0|   0|   1|
# |         US|   42507369|R1008R0427X1FG|B009KHHELW|      41559476|Duck Dynasty Seas...|Digital_Video_Dow...|          4|            0|          0|   N|                Y|        reality show|This series has m...| 2014-05-28|    true|   0|   0|   0|   1|   0|
# |         US|    2458036|R100AJRT6FE05K|B0048ZXXIO|     814772102|Team Umizoomi Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Educational for kids|My kid loves this...| 2014-06-27|    true|   0|   0|   0|   0|   1|
# |         US|   23459444|R100AOYGH18ZXK|B00GBDWZDU|     936264488|     Christmas Crush|Digital_Video_Dow...|          3|            0|          0|   N|                Y|         Three Stars|kind of dragged a...| 2015-05-20|   false|   0|   0|   1|   0|   0|
# |         US|   38247406|R100BC7LPZKRNN|B007SPQZMC|     192466294|Downton Abbey Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|Now I understand ...|I didn't know wha...| 2013-03-13|    true|   0|   0|   0|   0|   1|
# |         US|   45431492|R100E6GW7T8K8T|B00TPJE3ZK|     351396917|             Birdman|Digital_Video_Dow...|          4|            0|          1|   N|                Y|Well portrayed, c...|Great acting and ...| 2015-02-20|   false|   0|   0|   0|   1|   0|
# |         US|   53047960| R100IRNYUYV1E|B00J7JY812|     540211273|Orphan Black, Sea...|Digital_Video_Dow...|          4|            0|          0|   N|                Y|Great performance...|Great performance...| 2015-04-23|    true|   0|   0|   0|   1|   0|
# |         US|   19482080|R100K3H25R5WS0|B003AZCYCE|     730000855|  Justified Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                N|             Amazing|This is an amazin...| 2013-10-30|    true|   0|   0|   0|   0|   1|
# |         US|   48973249|R100PJ9LCWDNMK|B009HND1VG|     687442758|Death and The Civ...|Digital_Video_Dow...|          4|            2|          3|   N|                N|Audio Book Was Be...|Although the film...| 2014-03-12|   false|   0|   0|   0|   1|   0|
# |         US|   42529217|R100SWYL64JWQ9|B003363I3O|     106600129|LEGO: The Adventu...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|                   1| 2015-01-21|   false|   0|   0|   0|   0|   1|
# |         US|   43368651|R1012ZSHZ8EUJY|B004GTS81E|      38097401|   Cranford Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                N|   Wonderful Series!|I just loved this...| 2013-06-05|    true|   0|   0|   0|   0|   1|
# |         US|   45675760|R1018I6GYR9RXC|B00KFVWXPE|     938841809|The Sopranos: Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|          Great show|This is a great s...| 2014-06-05|    true|   0|   0|   0|   0|   1|
# |         US|   42254329| R101AQNQEQNH1|B006885LZM|     224139336|The Pacific Season 1|Digital_Video_Dow...|          5|            0|          0|   N|                Y|          Five Stars|Loved the 1st sea...| 2015-04-30|    true|   0|   0|   0|   0|   1|
# |         US|   15216617|R101FJHAGGVHVL|B00DTOYJJ2|     109469328|Breaking Bad The ...|Digital_Video_Dow...|          5|            0|          0|   N|                Y|Greatest televisi...|Best series EVER!...| 2014-01-06|    true|   0|   0|   0|   0|   1|
# |         US|   50896799|R1023HVVLBIBYV|B000I9X6NG|     572506954|Dodgeball: A True...|Digital_Video_Dow...|          1|            1|          2|   N|                Y|             Bad....|   Dumb and crude...| 2015-07-14|   false|   1|   0|   0|   0|   0|
# |         US|   35379296|R102MSR65GHIXU|B004JVXTL8|     408493771|Paranormal Activi...|Digital_Video_Dow...|          5|            0|          0|   N|                N|          Terrifying|This movie was fr...| 2015-01-09|   false|   0|   0|   0|   0|   1|
# |         US|   15303482|R1031FV2PBZTZ4|B004KAJLNS|     192466294|Downton Abbey Sea...|Digital_Video_Dow...|          5|            0|          0|   N|                N|Downton Abbey Sea...|This is a fantast...| 2014-01-14|    true|   0|   0|   0|   0|   1|
# |         US|   27051750|R103DUOHT7I4OT|B00F91RYL8|     757136861|         World War Z|Digital_Video_Dow...|          5|            0|          1|   N|                Y|          Five Stars|  Great zombie movie| 2015-03-10|   false|   0|   0|   0|   0|   1|
# |         US|   21780294|R103LYSTYMF48T|B00VLQX1GC|     464287565|        Last Knights|Digital_Video_Dow...|          4|            0|          0|   N|                Y|          Four Stars|I liked it, best ...| 2015-08-19|   false|   0|   0|   0|   1|   0|
# |         US|   20237654|R103N41PJJN0VE|B00FEHXCIG|     272231685|Iron Man 3 (Theat...|Digital_Video_Dow...|          3|            0|          0|   N|                Y|Cool action scene...|As you would expe...| 2013-11-26|   false|   0|   0|   1|   0|   0|
# +-----------+-----------+--------------+----------+--------------+--------------------+--------------------+-----------+-------------+-----------+----+-----------------+--------------------+--------------------+-----------+--------+----+----+----+----+----+
# only showing top 20 rows

# %% [markdown]
# ## Determine length of review

# %%
def count_words(x):
  return len(x.split(" "))

countWords = udf(count_words,"int")
complete_table = complete_table.withColumn('feedback_length',countWords)
complete_table.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-542d1877a16b> in <module>()
#       3
#       4 countWords = udf(count_words,"int")
# ----> 5 complete_table = complete_table.withColumn('feedback_length',countWords)
#       6 complete_table.show()
#
# /content/spark-3.0.3-bin-hadoop2.7/python/pyspark/sql/dataframe.py in withColumn(self, colName, col)
#    2093
#    2094         """
# -> 2095         assert isinstance(col, Column), "col should be Column"
#    2096         return DataFrame(self._jdf.withColumn(colName, col._jc), self.sql_ctx)
#    2097
#
# AssertionError: col should be Column

# %%
# Out:
# +--------+-----------------+------------------+---------------+
# |isSeries| avg(star_rating)|sum(helpful_votes)|count(isSeries)|
# +--------+-----------------+------------------+---------------+
# |    true|4.602062651843032|            360543|        1553825|
# |   false|3.952329750392877|           1667937|        2502693|
# +--------+-----------------+------------------+---------------+
